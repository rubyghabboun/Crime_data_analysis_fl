# %% [markdown]
# ### Data Exploration and Cleaning

# %%
import pandas as pd
import os

# %%
# Directory of all files 
nibrs_files = "Resources/"
# Listing the files in the directory
file_list = os.listdir(nibrs_files)
csv_files = [file for file in file_list if file.endswith('.csv')]
# Storing the dataframes
dataframes = {}
# Reading each csv file
for file in csv_files:
    file_path = os.path.join(nibrs_files, file)
    df_name = file.replace('.csv', '')
    dataframes[df_name] = pd.read_csv(file_path)
# Since the year is the same, drop the duplicate column 
for key in dataframes.keys():
    if 'data_year' in dataframes[key].columns:
        dataframes[key] = dataframes[key].drop('data_year', axis=1)
# Out:
# /var/folders/2v/w2v_wk9d5978rkz6gq_ydlqm0000gn/T/ipykernel_16304/2201067075.py:12: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes[df_name] = pd.read_csv(file_path)

# %%
# Merging the dataframes
df_combined = pd.merge(dataframes['NIBRS_VICTIM_OFFENSE'], dataframes['NIBRS_OFFENSE'],how='outer', on='offense_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_SUSPECT_USING'], how='outer', on='offense_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_BIAS_MOTIVATION'], how='outer', on='offense_id')
df_offender = pd.merge(dataframes['NIBRS_OFFENDER'], dataframes['NIBRS_AGE'],how='outer', on='age_id')
df_offender = pd.merge(df_offender, dataframes['REF_RACE'],how='outer', on='race_id')
df_offender = pd.merge(df_offender, dataframes['NIBRS_ETHNICITY'],how='outer', on='ethnicity_id')
df_victim = pd.merge(dataframes['NIBRS_VICTIM'], dataframes['NIBRS_AGE'],how='outer', on='age_id') 
df_victim = pd.merge(df_victim, dataframes['REF_RACE'],how='outer', on='race_id')
df_victim = pd.merge(df_victim, dataframes['NIBRS_ETHNICITY'],how='outer', on='ethnicity_id')
# Merging 'df_offender' and 'df_victim' dataframes
df_victim_offender = pd.merge(df_victim, df_offender, on='incident_id', how='outer', suffixes=('_victim', '_offender'))
# Merging 'df_combined'and 'df_victim_offender' dataframes
df_combined = pd.merge(df_combined, df_victim_offender, how='outer', left_on=['incident_id', 'victim_id'], right_on=['incident_id', 'victim_id'])
df_combined = pd.merge(df_combined, dataframes['NIBRS_incident'],how='outer', on='incident_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_PROPERTY'],how='outer', on='incident_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_PROPERTY_DESC'],how='outer', on='property_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_VICTIM_OFFENDER_REL'], how='outer', left_on=['victim_id', 'offender_id'], right_on=['victim_id', 'offender_id'])
df_combined = pd.merge(df_combined, dataframes['NIBRS_CRIMINAL_ACT'],how='outer', on='offense_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_WEAPON'],how='outer', on='offense_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_VICTIM_INJURY'],how='outer', on='victim_id')
df_combined = pd.merge(df_combined, dataframes['agencies'],how='outer', on='agency_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_OFFENSE_TYPE'],how='outer', on='offense_code')
df_combined = pd.merge(df_combined, dataframes['NIBRS_PROP_DESC_TYPE'],how='outer', on='prop_desc_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_LOCATION_TYPE'],how='outer', on='location_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_BIAS_LIST'],how='outer', on='bias_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_WEAPON_TYPE'],how='outer', on='weapon_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_RELATIONSHIP'],how='outer', on='relationship_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_VICTIM_CIRCUMSTANCES'],how='outer', on='victim_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_CIRCUMSTANCES'],how='outer', on='circumstances_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_CRIMINAL_ACT_TYPE'],how='outer', on='criminal_act_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_ACTIVITY_TYPE'],how='outer', on='activity_type_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_VICTIM_TYPE'],how='outer', on='victim_type_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_PROP_LOSS_TYPE'],how='outer', on='prop_loss_id')
df_combined = pd.merge(df_combined, dataframes['NIBRS_INJURY'],how='outer', on='injury_id')
df_complete = pd.merge(df_combined, dataframes['NIBRS_USING_LIST'],how='outer', on='suspect_using_id')

# %%
# Copying the dataframe to clean data
df_cleaned = df_complete.copy()

# %%
# Showing all columns of the dataframe
pd.set_option('display.max_columns', None)
df_cleaned
# Out:
#           victim_id   offense_id  incident_id offense_code  \
# 0       187407025.0  201782413.0  169127885.0          370
# 1       174718881.0  189055071.0  158047235.0          370
# 2       187407025.0  201782413.0  169127885.0          370
# 3       187407025.0  201782413.0  169127885.0          370
# 4       182585962.0  196943710.0  164923714.0          370
# ...             ...          ...          ...          ...
# 459269          NaN          NaN          NaN          NaN
# 459270          NaN          NaN          NaN          NaN
# 459271          NaN          NaN          NaN          NaN
# 459272          NaN          NaN          NaN          NaN
# 459273          NaN          NaN          NaN          NaN
#
#        attempt_complete_flag  location_id  num_premises_entered  \
# 0                          C         15.0                   NaN
# 1                          C         35.0                   NaN
# 2                          C         15.0                   NaN
# 3                          C         15.0                   NaN
# 4                          C         15.0                   NaN
# ...                      ...          ...                   ...
# 459269                   NaN          NaN                   NaN
# 459270                   NaN          NaN                   NaN
# 459271                   NaN          NaN                   NaN
# 459272                   NaN          NaN                   NaN
# 459273                   NaN          NaN                   NaN
#
#        method_entry_code  suspect_using_id  bias_id  victim_seq_num  \
# 0                    NaN               2.0     88.0             1.0
# 1                    NaN               2.0     88.0            98.0
# 2                    NaN               2.0     88.0             1.0
# 3                    NaN               2.0     88.0             1.0
# 4                    NaN               2.0     88.0             1.0
# ...                  ...               ...      ...             ...
# 459269               NaN               NaN      NaN             NaN
# 459270               NaN               NaN      NaN             NaN
# 459271               NaN               NaN      NaN             NaN
# 459272               NaN               NaN      NaN             NaN
# 459273               NaN               NaN      NaN             NaN
#
#         victim_type_id  assignment_type_id  activity_type_id  \
# 0                  8.0                 NaN               NaN
# 1                  8.0                 NaN               NaN
# 2                  8.0                 NaN               NaN
# 3                  8.0                 NaN               NaN
# 4                  8.0                 NaN               NaN
# ...                ...                 ...               ...
# 459269             NaN                 NaN               NaN
# 459270             NaN                 NaN               NaN
# 459271             NaN                 NaN               NaN
# 459272             NaN                 NaN               NaN
# 459273             NaN                 NaN               NaN
#
#         outside_agency_id  age_id_victim age_num_victim sex_code_victim  \
# 0                     NaN          104.0             NS               X
# 1                     NaN          104.0             NS               X
# 2                     NaN          104.0             NS               X
# 3                     NaN          104.0             NS               X
# 4                     NaN          104.0             NS               X
# ...                   ...            ...            ...             ...
# 459269                NaN            NaN            NaN             NaN
# 459270                NaN            NaN            NaN             NaN
# 459271                NaN            NaN            NaN             NaN
# 459272                NaN            NaN            NaN             NaN
# 459273                NaN            NaN            NaN             NaN
#
#         race_id_victim  ethnicity_id_victim resident_status_code  \
# 0                 99.0                 50.0                  NaN
# 1                 99.0                 50.0                  NaN
# 2                 99.0                 50.0                  NaN
# 3                 99.0                 50.0                  NaN
# 4                 99.0                 50.0                  NaN
# ...                ...                  ...                  ...
# 459269             NaN                  NaN                  NaN
# 459270             NaN                  NaN                  NaN
# 459271             NaN                  NaN                  NaN
# 459272             NaN                  NaN                  NaN
# 459273             NaN                  NaN                  NaN
#
#         age_range_low_num_victim  age_code_range_high age_code_victim  \
# 0                            NaN                  NaN              NS
# 1                            NaN                  NaN              NS
# 2                            NaN                  NaN              NS
# 3                            NaN                  NaN              NS
# 4                            NaN                  NaN              NS
# ...                          ...                  ...             ...
# 459269                       NaN                  NaN             NaN
# 459270                       NaN                  NaN             NaN
# 459271                       NaN                  NaN             NaN
# 459272                       NaN                  NaN             NaN
# 459273                       NaN                  NaN             NaN
#
#        age_name_victim race_code_victim race_desc_victim  sort_order_victim  \
# 0        Not Specified               NS    Not Specified               99.0
# 1        Not Specified               NS    Not Specified               99.0
# 2        Not Specified               NS    Not Specified               99.0
# 3        Not Specified               NS    Not Specified               99.0
# 4        Not Specified               NS    Not Specified               99.0
# ...                ...              ...              ...                ...
# 459269             NaN              NaN              NaN                NaN
# 459270             NaN              NaN              NaN                NaN
# 459271             NaN              NaN              NaN                NaN
# 459272             NaN              NaN              NaN                NaN
# 459273             NaN              NaN              NaN                NaN
#
#         start_year_victim  end_year_victim           notes_victim  \
# 0                     NaN              NaN  Race is not specified
# 1                     NaN              NaN  Race is not specified
# 2                     NaN              NaN  Race is not specified
# 3                     NaN              NaN  Race is not specified
# 4                     NaN              NaN  Race is not specified
# ...                   ...              ...                    ...
# 459269                NaN              NaN                    NaN
# 459270                NaN              NaN                    NaN
# 459271                NaN              NaN                    NaN
# 459272                NaN              NaN                    NaN
# 459273                NaN              NaN                    NaN
#
#        ethnicity_code_victim ethnicity_name_victim  offender_id  \
# 0                          X         Not Specified  191997464.0
# 1                          X         Not Specified  179473577.0
# 2                          X         Not Specified  191997464.0
# 3                          X         Not Specified  191997464.0
# 4                          X         Not Specified  187239644.0
# ...                      ...                   ...          ...
# 459269                   NaN                   NaN          NaN
# 459270                   NaN                   NaN          NaN
# 459271                   NaN                   NaN          NaN
# 459272                   NaN                   NaN          NaN
# 459273                   NaN                   NaN          NaN
#
#         offender_seq_num  age_id_offender age_num_offender sex_code_offender  \
# 0                    1.0             33.0               30                 M
# 1                    1.0             27.0               24                 M
# 2                    1.0             33.0               30                 M
# 3                    1.0             33.0               30                 M
# 4                    0.0            103.0               00                 X
# ...                  ...              ...              ...               ...
# 459269               NaN              NaN              NaN               NaN
# 459270               NaN              NaN              NaN               NaN
# 459271               NaN              NaN              NaN               NaN
# 459272               NaN              NaN              NaN               NaN
# 459273               NaN              NaN              NaN               NaN
#
#         race_id_offender  ethnicity_id_offender  age_range_low_num_offender  \
# 0                   10.0                   20.0                        30.0
# 1                   20.0                   40.0                        24.0
# 2                   10.0                   20.0                        30.0
# 3                   10.0                   20.0                        30.0
# 4                   99.0                   50.0                         NaN
# ...                  ...                    ...                         ...
# 459269               NaN                    NaN                         NaN
# 459270               NaN                    NaN                         NaN
# 459271               NaN                    NaN                         NaN
# 459272               NaN                    NaN                         NaN
# 459273               NaN                    NaN                         NaN
#
#         age_range_high_num age_code_offender age_name_offender  \
# 0                      NaN                30      30 Years Old
# 1                      NaN                24      24 Years Old
# 2                      NaN                30      30 Years Old
# 3                      NaN                30      30 Years Old
# 4                      NaN                00           Unknown
# ...                    ...               ...               ...
# 459269                 NaN               NaN               NaN
# 459270                 NaN               NaN               NaN
# 459271                 NaN               NaN               NaN
# 459272                 NaN               NaN               NaN
# 459273                 NaN               NaN               NaN
#
#        race_code_offender         race_desc_offender  sort_order_offender  \
# 0                       W                      White                 10.0
# 1                       B  Black or African American                 20.0
# 2                       W                      White                 10.0
# 3                       W                      White                 10.0
# 4                      NS              Not Specified                 99.0
# ...                   ...                        ...                  ...
# 459269                NaN                        NaN                  NaN
# 459270                NaN                        NaN                  NaN
# 459271                NaN                        NaN                  NaN
# 459272                NaN                        NaN                  NaN
# 459273                NaN                        NaN                  NaN
#
#         start_year_offender  end_year_offender         notes_offender  \
# 0                       NaN                NaN                    NaN
# 1                       NaN                NaN                    NaN
# 2                       NaN                NaN                    NaN
# 3                       NaN                NaN                    NaN
# 4                       NaN                NaN  Race is not specified
# ...                     ...                ...                    ...
# 459269                  NaN                NaN                    NaN
# 459270                  NaN                NaN                    NaN
# 459271                  NaN                NaN                    NaN
# 459272                  NaN                NaN                    NaN
# 459273                  NaN                NaN                    NaN
#
#        ethnicity_code_offender ethnicity_name_offender  agency_id  \
# 0                            N  Not Hispanic or Latino     2319.0
# 1                            U                 Unknown     2615.0
# 2                            N  Not Hispanic or Latino     2319.0
# 3                            N  Not Hispanic or Latino     2319.0
# 4                            X           Not Specified     2580.0
# ...                        ...                     ...        ...
# 459269                     NaN                     NaN        NaN
# 459270                     NaN                     NaN        NaN
# 459271                     NaN                     NaN        NaN
# 459272                     NaN                     NaN        NaN
# 459273                     NaN                     NaN        NaN
#
#         nibrs_month_id cargo_theft_flag          submission_date  \
# 0           44445200.0                f  2023-04-03 14:05:29.801
# 1           44165952.0                f  2022-08-29 22:21:11.405
# 2           44445200.0                f  2023-04-03 14:05:29.801
# 3           44445200.0                f  2023-04-03 14:05:29.801
# 4           44219109.0                f  2023-01-20 19:34:46.622
# ...                ...              ...                      ...
# 459269             NaN              NaN                      NaN
# 459270             NaN              NaN                      NaN
# 459271             NaN              NaN                      NaN
# 459272             NaN              NaN                      NaN
# 459273             NaN              NaN                      NaN
#
#        incident_date report_date_flag  incident_hour  cleared_except_id  \
# 0         2022-04-07                f            0.0                6.0
# 1         2022-05-02                f            0.0                6.0
# 2         2022-04-07                f            0.0                6.0
# 3         2022-04-07                f            0.0                6.0
# 4         2022-10-25                f           16.0                6.0
# ...              ...              ...            ...                ...
# 459269           NaN              NaN            NaN                NaN
# 459270           NaN              NaN            NaN                NaN
# 459271           NaN              NaN            NaN                NaN
# 459272           NaN              NaN            NaN                NaN
# 459273           NaN              NaN            NaN                NaN
#
#        cleared_except_date incident_status  data_home orig_format  \
# 0                      NaN        ACCEPTED        NaN           X
# 1                      NaN        ACCEPTED        NaN           X
# 2                      NaN        ACCEPTED        NaN           X
# 3                      NaN        ACCEPTED        NaN           X
# 4                      NaN        ACCEPTED        NaN           X
# ...                    ...             ...        ...         ...
# 459269                 NaN             NaN        NaN         NaN
# 459270                 NaN             NaN        NaN         NaN
# 459271                 NaN             NaN        NaN         NaN
# 459272                 NaN             NaN        NaN         NaN
# 459273                 NaN             NaN        NaN         NaN
#
#                 did  property_id  prop_loss_id  stolen_count  recovered_count  \
# 0       181967491.0          NaN           NaN           NaN              NaN
# 1       152981707.0          NaN           NaN           NaN              NaN
# 2       181967491.0          NaN           NaN           NaN              NaN
# 3       181967491.0          NaN           NaN           NaN              NaN
# 4       170471177.0          NaN           NaN           NaN              NaN
# ...             ...          ...           ...           ...              ...
# 459269          NaN          NaN           NaN           NaN              NaN
# 459270          NaN          NaN           NaN           NaN              NaN
# 459271          NaN          NaN           NaN           NaN              NaN
# 459272          NaN          NaN           NaN           NaN              NaN
# 459273          NaN          NaN           NaN           NaN              NaN
#
#         prop_desc_id  property_value date_recovered  nibrs_prop_desc_id  \
# 0                NaN             NaN            NaN                 NaN
# 1                NaN             NaN            NaN                 NaN
# 2                NaN             NaN            NaN                 NaN
# 3                NaN             NaN            NaN                 NaN
# 4                NaN             NaN            NaN                 NaN
# ...              ...             ...            ...                 ...
# 459269           NaN             NaN            NaN                 NaN
# 459270           NaN             NaN            NaN                 NaN
# 459271           NaN             NaN            NaN                 NaN
# 459272           NaN             NaN            NaN                 NaN
# 459273           NaN             NaN            NaN                 NaN
#
#         relationship_id  nibrs_victim_offender_id  criminal_act_id  weapon_id  \
# 0                   NaN                       NaN              2.0        NaN
# 1                   NaN                       NaN              2.0        NaN
# 2                   NaN                       NaN              5.0        NaN
# 3                   NaN                       NaN              6.0        NaN
# 4                   NaN                       NaN              6.0        NaN
# ...                 ...                       ...              ...        ...
# 459269              NaN                       NaN              NaN        NaN
# 459270              NaN                       NaN              NaN        NaN
# 459271              NaN                       NaN              NaN        NaN
# 459272              NaN                       NaN              NaN        NaN
# 459273              NaN                       NaN              NaN        NaN
#
#         nibrs_weapon_id  injury_id  yearly_agency_id        ori legacy_ori  \
# 0                   NaN        NaN        23192022.0  FL0010000  FL0010000
# 1                   NaN        NaN        26152022.0  FL0160000  FL0160000
# 2                   NaN        NaN        23192022.0  FL0010000  FL0010000
# 3                   NaN        NaN        23192022.0  FL0010000  FL0010000
# 4                   NaN        NaN        25802022.0  FL0139100  FL0139100
# ...                 ...        ...               ...        ...        ...
# 459269              NaN        NaN               NaN        NaN        NaN
# 459270              NaN        NaN               NaN        NaN        NaN
# 459271              NaN        NaN               NaN        NaN        NaN
# 459272              NaN        NaN               NaN        NaN        NaN
# 459273              NaN        NaN               NaN        NaN        NaN
#
#         covered_by_legacy_ori direct_contributor_flag dormant_flag  \
# 0                         NaN                       N            N
# 1                         NaN                       N            N
# 2                         NaN                       N            N
# 3                         NaN                       N            N
# 4                         NaN                       N            N
# ...                       ...                     ...          ...
# 459269                    NaN                     NaN          NaN
# 459270                    NaN                     NaN          NaN
# 459271                    NaN                     NaN          NaN
# 459272                    NaN                     NaN          NaN
# 459273                    NaN                     NaN          NaN
#
#         dormant_year reporting_type                ucr_agency_name  \
# 0                NaN              I                        ALACHUA
# 1                NaN              I  JACKSONVILLE SHERIFF'S OFFICE
# 2                NaN              I                        ALACHUA
# 3                NaN              I                        ALACHUA
# 4                NaN              I                       AVENTURA
# ...              ...            ...                            ...
# 459269           NaN            NaN                            NaN
# 459270           NaN            NaN                            NaN
# 459271           NaN            NaN                            NaN
# 459272           NaN            NaN                            NaN
# 459273           NaN            NaN                            NaN
#
#                           ncic_agency_name                pub_agency_name  \
# 0                ALACHUA CO SO GAINESVILLE                        Alachua
# 1                 DUVAL CO SO JACKSONVILLE  Jacksonville Sheriff's Office
# 2                ALACHUA CO SO GAINESVILLE                        Alachua
# 3                ALACHUA CO SO GAINESVILLE                        Alachua
# 4       CITY OF AVENTURA POLICE DEPARTMENT                       Aventura
# ...                                    ...                            ...
# 459269                                 NaN                            NaN
# 459270                                 NaN                            NaN
# 459271                                 NaN                            NaN
# 459272                                 NaN                            NaN
# 459273                                 NaN                            NaN
#
#        pub_agency_unit agency_status  state_id state_name state_abbr  \
# 0                  NaN             A      12.0    Florida         FL
# 1                  NaN             A      12.0    Florida         FL
# 2                  NaN             A      12.0    Florida         FL
# 3                  NaN             A      12.0    Florida         FL
# 4                  NaN             A      12.0    Florida         FL
# ...                ...           ...       ...        ...        ...
# 459269             NaN           NaN       NaN        NaN        NaN
# 459270             NaN           NaN       NaN        NaN        NaN
# 459271             NaN           NaN       NaN        NaN        NaN
# 459272             NaN           NaN       NaN        NaN        NaN
# 459273             NaN           NaN       NaN        NaN        NaN
#
#        state_postal_abbr  division_code   division_name  region_code  \
# 0                     FL            5.0  South Atlantic          3.0
# 1                     FL            5.0  South Atlantic          3.0
# 2                     FL            5.0  South Atlantic          3.0
# 3                     FL            5.0  South Atlantic          3.0
# 4                     FL            5.0  South Atlantic          3.0
# ...                  ...            ...             ...          ...
# 459269               NaN            NaN             NaN          NaN
# 459270               NaN            NaN             NaN          NaN
# 459271               NaN            NaN             NaN          NaN
# 459272               NaN            NaN             NaN          NaN
# 459273               NaN            NaN             NaN          NaN
#
#        region_name region_desc agency_type_name  population  \
# 0            South  Region III           County    124750.0
# 1            South  Region III           County    971282.0
# 2            South  Region III           County    124750.0
# 3            South  Region III           County    124750.0
# 4            South  Region III             City     38484.0
# ...            ...         ...              ...         ...
# 459269         NaN         NaN              NaN         NaN
# 459270         NaN         NaN              NaN         NaN
# 459271         NaN         NaN              NaN         NaN
# 459272         NaN         NaN              NaN         NaN
# 459273         NaN         NaN              NaN         NaN
#
#         submitting_agency_id        sai  \
# 0                    23362.0  FLUCR0001
# 1                    23362.0  FLUCR0001
# 2                    23362.0  FLUCR0001
# 3                    23362.0  FLUCR0001
# 4                    23362.0  FLUCR0001
# ...                      ...        ...
# 459269                   NaN        NaN
# 459270                   NaN        NaN
# 459271                   NaN        NaN
# 459272                   NaN        NaN
# 459273                   NaN        NaN
#
#                                    submitting_agency_name suburban_area_flag  \
# 0       Florida Department of Law Enforcement Uniform ...                  Y
# 1       Florida Department of Law Enforcement Uniform ...                  Y
# 2       Florida Department of Law Enforcement Uniform ...                  Y
# 3       Florida Department of Law Enforcement Uniform ...                  Y
# 4       Florida Department of Law Enforcement Uniform ...                  Y
# ...                                                   ...                ...
# 459269                                                NaN                NaN
# 459270                                                NaN                NaN
# 459271                                                NaN                NaN
# 459272                                                NaN                NaN
# 459273                                                NaN                NaN
#
#         population_group_id population_group_code  \
# 0                      19.0                    9A
# 1                      19.0                    9A
# 2                      19.0                    9A
# 3                      19.0                    9A
# 4                       8.0                     4
# ...                     ...                   ...
# 459269                  NaN                   NaN
# 459270                  NaN                   NaN
# 459271                  NaN                   NaN
# 459272                  NaN                   NaN
# 459273                  NaN                   NaN
#
#                  population_group_desc  parent_pop_group_code  \
# 0         MSA counties 100,000 or over                    9.0
# 1         MSA counties 100,000 or over                    9.0
# 2         MSA counties 100,000 or over                    9.0
# 3         MSA counties 100,000 or over                    9.0
# 4       Cities from 25,000 thru 49,999                    4.0
# ...                                ...                    ...
# 459269                             NaN                    NaN
# 459270                             NaN                    NaN
# 459271                             NaN                    NaN
# 459272                             NaN                    NaN
# 459273                             NaN                    NaN
#
#                  parent_pop_group_desc mip_flag  pop_sort_order  \
# 0                         MSA Counties        Y            19.0
# 1                         MSA Counties        Y            19.0
# 2                         MSA Counties        Y            19.0
# 3                         MSA Counties        Y            19.0
# 4       Cities from 25,000 thru 49,999        N             8.0
# ...                                ...      ...             ...
# 459269                             NaN      NaN             NaN
# 459270                             NaN      NaN             NaN
# 459271                             NaN      NaN             NaN
# 459272                             NaN      NaN             NaN
# 459273                             NaN      NaN             NaN
#
#         summary_rape_def pe_reported_flag  male_officer  male_civilian  \
# 0                    NaN                Y         227.0           41.0
# 1                    NaN                N           NaN            NaN
# 2                    NaN                Y         227.0           41.0
# 3                    NaN                Y         227.0           41.0
# 4                    NaN                Y          77.0           11.0
# ...                  ...              ...           ...            ...
# 459269               NaN              NaN           NaN            NaN
# 459270               NaN              NaN           NaN            NaN
# 459271               NaN              NaN           NaN            NaN
# 459272               NaN              NaN           NaN            NaN
# 459273               NaN              NaN           NaN            NaN
#
#         male_officer+male_civilian  female_officer  female_civilian  \
# 0                            268.0            19.0             83.0
# 1                              NaN             NaN              NaN
# 2                            268.0            19.0             83.0
# 3                            268.0            19.0             83.0
# 4                             88.0            14.0             21.0
# ...                            ...             ...              ...
# 459269                         NaN             NaN              NaN
# 459270                         NaN             NaN              NaN
# 459271                         NaN             NaN              NaN
# 459272                         NaN             NaN              NaN
# 459273                         NaN             NaN              NaN
#
#         female_officer+female_civilian  officer_rate  employee_rate  \
# 0                                102.0           2.0            3.0
# 1                                  NaN           NaN            NaN
# 2                                102.0           2.0            3.0
# 3                                102.0           2.0            3.0
# 4                                 35.0           2.4            3.2
# ...                                ...           ...            ...
# 459269                             NaN           NaN            NaN
# 459270                             NaN           NaN            NaN
# 459271                             NaN           NaN            NaN
# 459272                             NaN           NaN            NaN
# 459273                             NaN           NaN            NaN
#
#        nibrs_cert_date nibrs_start_date nibrs_leoka_start_date  \
# 0           2021-01-01       2022-02-01             2022-05-01
# 1           2021-01-01       2021-10-01             2022-06-01
# 2           2021-01-01       2022-02-01             2022-05-01
# 3           2021-01-01       2022-02-01             2022-05-01
# 4           2021-01-01       2021-01-01             2022-06-01
# ...                ...              ...                    ...
# 459269             NaN              NaN                    NaN
# 459270             NaN              NaN                    NaN
# 459271             NaN              NaN                    NaN
# 459272             NaN              NaN                    NaN
# 459273             NaN              NaN                    NaN
#
#        nibrs_ct_start_date nibrs_multi_bias_start_date  \
# 0               2022-05-01                  2022-05-01
# 1               2022-06-01                  2022-06-01
# 2               2022-05-01                  2022-05-01
# 3               2022-05-01                  2022-05-01
# 4               2022-06-01                  2022-06-01
# ...                    ...                         ...
# 459269                 NaN                         NaN
# 459270                 NaN                         NaN
# 459271                 NaN                         NaN
# 459272                 NaN                         NaN
# 459273                 NaN                         NaN
#
#        nibrs_off_eth_start_date covered_flag county_name  \
# 0                    2022-05-01            N     ALACHUA
# 1                    2022-06-01            N       DUVAL
# 2                    2022-05-01            N     ALACHUA
# 3                    2022-05-01            N     ALACHUA
# 4                    2022-06-01            N  MIAMI-DADE
# ...                         ...          ...         ...
# 459269                      NaN          NaN         NaN
# 459270                      NaN          NaN         NaN
# 459271                      NaN          NaN         NaN
# 459272                      NaN          NaN         NaN
# 459273                      NaN          NaN         NaN
#
#                                        msa_name publishable_flag participated  \
# 0                               Gainesville, FL                Y            Y
# 1                              Jacksonville, FL                Y            Y
# 2                               Gainesville, FL                Y            Y
# 3                               Gainesville, FL                Y            Y
# 4       Miami-Fort Lauderdale-Pompano Beach, FL                Y            Y
# ...                                         ...              ...          ...
# 459269                                      NaN              NaN          NaN
# 459270                                      NaN              NaN          NaN
# 459271                                      NaN              NaN          NaN
# 459272                                      NaN              NaN          NaN
# 459273                                      NaN              NaN          NaN
#
#        nibrs_participated                  offense_name crime_against ct_flag  \
# 0                       Y  Pornography/Obscene Material       Society       f
# 1                       Y  Pornography/Obscene Material       Society       f
# 2                       Y  Pornography/Obscene Material       Society       f
# 3                       Y  Pornography/Obscene Material       Society       f
# 4                       Y  Pornography/Obscene Material       Society       f
# ...                   ...                           ...           ...     ...
# 459269                NaN                           NaN           NaN     NaN
# 459270                NaN                           NaN           NaN     NaN
# 459271                NaN                           NaN           NaN     NaN
# 459272                NaN                           NaN           NaN     NaN
# 459273                NaN                           NaN           NaN     NaN
#
#        hc_flag hc_code         offense_category_name offense_group  \
# 0            t          Pornography/Obscene Material             A
# 1            t          Pornography/Obscene Material             A
# 2            t          Pornography/Obscene Material             A
# 3            t          Pornography/Obscene Material             A
# 4            t          Pornography/Obscene Material             A
# ...        ...     ...                           ...           ...
# 459269     NaN     NaN                           NaN           NaN
# 459270     NaN     NaN                           NaN           NaN
# 459271     NaN     NaN                           NaN           NaN
# 459272     NaN     NaN                           NaN           NaN
# 459273     NaN     NaN                           NaN           NaN
#
#        prop_desc_name  prop_desc_code  location_code   location_name  \
# 0                 NaN             NaN           58.0      Cyberspace
# 1                 NaN             NaN           20.0  Residence/Home
# 2                 NaN             NaN           58.0      Cyberspace
# 3                 NaN             NaN           58.0      Cyberspace
# 4                 NaN             NaN           58.0      Cyberspace
# ...               ...             ...            ...             ...
# 459269            NaN             NaN            NaN             NaN
# 459270            NaN             NaN            NaN             NaN
# 459271            NaN             NaN            NaN             NaN
# 459272            NaN             NaN            NaN             NaN
# 459273            NaN             NaN            NaN             NaN
#
#         bias_code bias_category       bias_desc weapon_code weapon_name  \
# 0            88.0  None/Unknown  None (no bias)         NaN         NaN
# 1            88.0  None/Unknown  None (no bias)         NaN         NaN
# 2            88.0  None/Unknown  None (no bias)         NaN         NaN
# 3            88.0  None/Unknown  None (no bias)         NaN         NaN
# 4            88.0  None/Unknown  None (no bias)         NaN         NaN
# ...           ...           ...             ...         ...         ...
# 459269        NaN           NaN             NaN         NaN         NaN
# 459270        NaN           NaN             NaN         NaN         NaN
# 459271        NaN           NaN             NaN         NaN         NaN
# 459272        NaN           NaN             NaN         NaN         NaN
# 459273        NaN           NaN             NaN         NaN         NaN
#
#        shr_flag relationship_code relationship_name  circumstances_id  \
# 0           NaN               NaN               NaN               NaN
# 1           NaN               NaN               NaN               NaN
# 2           NaN               NaN               NaN               NaN
# 3           NaN               NaN               NaN               NaN
# 4           NaN               NaN               NaN               NaN
# ...         ...               ...               ...               ...
# 459269      NaN               NaN               NaN              30.0
# 459270      NaN               NaN               NaN              31.0
# 459271      NaN               NaN               NaN              32.0
# 459272      NaN               NaN               NaN              33.0
# 459273      NaN               NaN               NaN              34.0
#
#         justifiable_force_id circumstance_type  circumstance_code  \
# 0                        NaN               NaN                NaN
# 1                        NaN               NaN                NaN
# 2                        NaN               NaN                NaN
# 3                        NaN               NaN                NaN
# 4                        NaN               NaN                NaN
# ...                      ...               ...                ...
# 459269                   NaN                 N               30.0
# 459270                   NaN                 N               31.0
# 459271                   NaN                 N               32.0
# 459272                   NaN                 N               33.0
# 459273                   NaN                 N               34.0
#
#                       circumstance_name criminal_act_code  \
# 0                                   NaN                 C
# 1                                   NaN                 C
# 2                                   NaN                 O
# 3                                   NaN                 P
# 4                                   NaN                 P
# ...                                 ...               ...
# 459269        Child Playing With Weapon               NaN
# 459270            Gun-Cleaning Accident               NaN
# 459271                 Hunting Accident               NaN
# 459272  Other Negligent Weapon Handling               NaN
# 459273         Other Negligent Killings               NaN
#
#                            criminal_act_name  \
# 0       Cultivating/Manufacturing/Publishing
# 1       Cultivating/Manufacturing/Publishing
# 2              Operating/Promoting/Assisting
# 3                      Possessing/Concealing
# 4                      Possessing/Concealing
# ...                                      ...
# 459269                                   NaN
# 459270                                   NaN
# 459271                                   NaN
# 459272                                   NaN
# 459273                                   NaN
#
#                                         criminal_act_desc  activity_type_code  \
# 0       Cultivating/Manufacturing/Publishing (i.e., pr...                 NaN
# 1       Cultivating/Manufacturing/Publishing (i.e., pr...                 NaN
# 2                           Operating/Promoting/Assisting                 NaN
# 3                                   Possessing/Concealing                 NaN
# 4                                   Possessing/Concealing                 NaN
# ...                                                   ...                 ...
# 459269                                                NaN                 NaN
# 459270                                                NaN                 NaN
# 459271                                                NaN                 NaN
# 459272                                                NaN                 NaN
# 459273                                                NaN                 NaN
#
#        activity_type_name victim_type_code victim_type_name prop_loss_name  \
# 0                     NaN                S   Society/Public            NaN
# 1                     NaN                S   Society/Public            NaN
# 2                     NaN                S   Society/Public            NaN
# 3                     NaN                S   Society/Public            NaN
# 4                     NaN                S   Society/Public            NaN
# ...                   ...              ...              ...            ...
# 459269                NaN              NaN              NaN            NaN
# 459270                NaN              NaN              NaN            NaN
# 459271                NaN              NaN              NaN            NaN
# 459272                NaN              NaN              NaN            NaN
# 459273                NaN              NaN              NaN            NaN
#
#        prop_loss_desc injury_code injury_name suspect_using_code  \
# 0                 NaN         NaN         NaN                  C
# 1                 NaN         NaN         NaN                  C
# 2                 NaN         NaN         NaN                  C
# 3                 NaN         NaN         NaN                  C
# 4                 NaN         NaN         NaN                  C
# ...               ...         ...         ...                ...
# 459269            NaN         NaN         NaN                NaN
# 459270            NaN         NaN         NaN                NaN
# 459271            NaN         NaN         NaN                NaN
# 459272            NaN         NaN         NaN                NaN
# 459273            NaN         NaN         NaN                NaN
#
#                            suspect_using_name
# 0       Computer Equipment (Handheld Devices)
# 1       Computer Equipment (Handheld Devices)
# 2       Computer Equipment (Handheld Devices)
# 3       Computer Equipment (Handheld Devices)
# 4       Computer Equipment (Handheld Devices)
# ...                                       ...
# 459269                                    NaN
# 459270                                    NaN
# 459271                                    NaN
# 459272                                    NaN
# 459273                                    NaN
#
# [459274 rows x 173 columns]

# %%
# Removing columns where all values are null
df_cleaned = df_cleaned.dropna(axis=1, how='all')
df_cleaned
# Out:
#           victim_id   offense_id  incident_id offense_code  \
# 0       187407025.0  201782413.0  169127885.0          370
# 1       174718881.0  189055071.0  158047235.0          370
# 2       187407025.0  201782413.0  169127885.0          370
# 3       187407025.0  201782413.0  169127885.0          370
# 4       182585962.0  196943710.0  164923714.0          370
# ...             ...          ...          ...          ...
# 459269          NaN          NaN          NaN          NaN
# 459270          NaN          NaN          NaN          NaN
# 459271          NaN          NaN          NaN          NaN
# 459272          NaN          NaN          NaN          NaN
# 459273          NaN          NaN          NaN          NaN
#
#        attempt_complete_flag  location_id  num_premises_entered  \
# 0                          C         15.0                   NaN
# 1                          C         35.0                   NaN
# 2                          C         15.0                   NaN
# 3                          C         15.0                   NaN
# 4                          C         15.0                   NaN
# ...                      ...          ...                   ...
# 459269                   NaN          NaN                   NaN
# 459270                   NaN          NaN                   NaN
# 459271                   NaN          NaN                   NaN
# 459272                   NaN          NaN                   NaN
# 459273                   NaN          NaN                   NaN
#
#        method_entry_code  suspect_using_id  bias_id  victim_seq_num  \
# 0                    NaN               2.0     88.0             1.0
# 1                    NaN               2.0     88.0            98.0
# 2                    NaN               2.0     88.0             1.0
# 3                    NaN               2.0     88.0             1.0
# 4                    NaN               2.0     88.0             1.0
# ...                  ...               ...      ...             ...
# 459269               NaN               NaN      NaN             NaN
# 459270               NaN               NaN      NaN             NaN
# 459271               NaN               NaN      NaN             NaN
# 459272               NaN               NaN      NaN             NaN
# 459273               NaN               NaN      NaN             NaN
#
#         victim_type_id  assignment_type_id  activity_type_id  \
# 0                  8.0                 NaN               NaN
# 1                  8.0                 NaN               NaN
# 2                  8.0                 NaN               NaN
# 3                  8.0                 NaN               NaN
# 4                  8.0                 NaN               NaN
# ...                ...                 ...               ...
# 459269             NaN                 NaN               NaN
# 459270             NaN                 NaN               NaN
# 459271             NaN                 NaN               NaN
# 459272             NaN                 NaN               NaN
# 459273             NaN                 NaN               NaN
#
#         outside_agency_id  age_id_victim age_num_victim sex_code_victim  \
# 0                     NaN          104.0             NS               X
# 1                     NaN          104.0             NS               X
# 2                     NaN          104.0             NS               X
# 3                     NaN          104.0             NS               X
# 4                     NaN          104.0             NS               X
# ...                   ...            ...            ...             ...
# 459269                NaN            NaN            NaN             NaN
# 459270                NaN            NaN            NaN             NaN
# 459271                NaN            NaN            NaN             NaN
# 459272                NaN            NaN            NaN             NaN
# 459273                NaN            NaN            NaN             NaN
#
#         race_id_victim  ethnicity_id_victim resident_status_code  \
# 0                 99.0                 50.0                  NaN
# 1                 99.0                 50.0                  NaN
# 2                 99.0                 50.0                  NaN
# 3                 99.0                 50.0                  NaN
# 4                 99.0                 50.0                  NaN
# ...                ...                  ...                  ...
# 459269             NaN                  NaN                  NaN
# 459270             NaN                  NaN                  NaN
# 459271             NaN                  NaN                  NaN
# 459272             NaN                  NaN                  NaN
# 459273             NaN                  NaN                  NaN
#
#         age_range_low_num_victim  age_code_range_high age_code_victim  \
# 0                            NaN                  NaN              NS
# 1                            NaN                  NaN              NS
# 2                            NaN                  NaN              NS
# 3                            NaN                  NaN              NS
# 4                            NaN                  NaN              NS
# ...                          ...                  ...             ...
# 459269                       NaN                  NaN             NaN
# 459270                       NaN                  NaN             NaN
# 459271                       NaN                  NaN             NaN
# 459272                       NaN                  NaN             NaN
# 459273                       NaN                  NaN             NaN
#
#        age_name_victim race_code_victim race_desc_victim  sort_order_victim  \
# 0        Not Specified               NS    Not Specified               99.0
# 1        Not Specified               NS    Not Specified               99.0
# 2        Not Specified               NS    Not Specified               99.0
# 3        Not Specified               NS    Not Specified               99.0
# 4        Not Specified               NS    Not Specified               99.0
# ...                ...              ...              ...                ...
# 459269             NaN              NaN              NaN                NaN
# 459270             NaN              NaN              NaN                NaN
# 459271             NaN              NaN              NaN                NaN
# 459272             NaN              NaN              NaN                NaN
# 459273             NaN              NaN              NaN                NaN
#
#         start_year_victim  end_year_victim           notes_victim  \
# 0                     NaN              NaN  Race is not specified
# 1                     NaN              NaN  Race is not specified
# 2                     NaN              NaN  Race is not specified
# 3                     NaN              NaN  Race is not specified
# 4                     NaN              NaN  Race is not specified
# ...                   ...              ...                    ...
# 459269                NaN              NaN                    NaN
# 459270                NaN              NaN                    NaN
# 459271                NaN              NaN                    NaN
# 459272                NaN              NaN                    NaN
# 459273                NaN              NaN                    NaN
#
#        ethnicity_code_victim ethnicity_name_victim  offender_id  \
# 0                          X         Not Specified  191997464.0
# 1                          X         Not Specified  179473577.0
# 2                          X         Not Specified  191997464.0
# 3                          X         Not Specified  191997464.0
# 4                          X         Not Specified  187239644.0
# ...                      ...                   ...          ...
# 459269                   NaN                   NaN          NaN
# 459270                   NaN                   NaN          NaN
# 459271                   NaN                   NaN          NaN
# 459272                   NaN                   NaN          NaN
# 459273                   NaN                   NaN          NaN
#
#         offender_seq_num  age_id_offender age_num_offender sex_code_offender  \
# 0                    1.0             33.0               30                 M
# 1                    1.0             27.0               24                 M
# 2                    1.0             33.0               30                 M
# 3                    1.0             33.0               30                 M
# 4                    0.0            103.0               00                 X
# ...                  ...              ...              ...               ...
# 459269               NaN              NaN              NaN               NaN
# 459270               NaN              NaN              NaN               NaN
# 459271               NaN              NaN              NaN               NaN
# 459272               NaN              NaN              NaN               NaN
# 459273               NaN              NaN              NaN               NaN
#
#         race_id_offender  ethnicity_id_offender  age_range_low_num_offender  \
# 0                   10.0                   20.0                        30.0
# 1                   20.0                   40.0                        24.0
# 2                   10.0                   20.0                        30.0
# 3                   10.0                   20.0                        30.0
# 4                   99.0                   50.0                         NaN
# ...                  ...                    ...                         ...
# 459269               NaN                    NaN                         NaN
# 459270               NaN                    NaN                         NaN
# 459271               NaN                    NaN                         NaN
# 459272               NaN                    NaN                         NaN
# 459273               NaN                    NaN                         NaN
#
#         age_range_high_num age_code_offender age_name_offender  \
# 0                      NaN                30      30 Years Old
# 1                      NaN                24      24 Years Old
# 2                      NaN                30      30 Years Old
# 3                      NaN                30      30 Years Old
# 4                      NaN                00           Unknown
# ...                    ...               ...               ...
# 459269                 NaN               NaN               NaN
# 459270                 NaN               NaN               NaN
# 459271                 NaN               NaN               NaN
# 459272                 NaN               NaN               NaN
# 459273                 NaN               NaN               NaN
#
#        race_code_offender         race_desc_offender  sort_order_offender  \
# 0                       W                      White                 10.0
# 1                       B  Black or African American                 20.0
# 2                       W                      White                 10.0
# 3                       W                      White                 10.0
# 4                      NS              Not Specified                 99.0
# ...                   ...                        ...                  ...
# 459269                NaN                        NaN                  NaN
# 459270                NaN                        NaN                  NaN
# 459271                NaN                        NaN                  NaN
# 459272                NaN                        NaN                  NaN
# 459273                NaN                        NaN                  NaN
#
#         start_year_offender  end_year_offender         notes_offender  \
# 0                       NaN                NaN                    NaN
# 1                       NaN                NaN                    NaN
# 2                       NaN                NaN                    NaN
# 3                       NaN                NaN                    NaN
# 4                       NaN                NaN  Race is not specified
# ...                     ...                ...                    ...
# 459269                  NaN                NaN                    NaN
# 459270                  NaN                NaN                    NaN
# 459271                  NaN                NaN                    NaN
# 459272                  NaN                NaN                    NaN
# 459273                  NaN                NaN                    NaN
#
#        ethnicity_code_offender ethnicity_name_offender  agency_id  \
# 0                            N  Not Hispanic or Latino     2319.0
# 1                            U                 Unknown     2615.0
# 2                            N  Not Hispanic or Latino     2319.0
# 3                            N  Not Hispanic or Latino     2319.0
# 4                            X           Not Specified     2580.0
# ...                        ...                     ...        ...
# 459269                     NaN                     NaN        NaN
# 459270                     NaN                     NaN        NaN
# 459271                     NaN                     NaN        NaN
# 459272                     NaN                     NaN        NaN
# 459273                     NaN                     NaN        NaN
#
#         nibrs_month_id cargo_theft_flag          submission_date  \
# 0           44445200.0                f  2023-04-03 14:05:29.801
# 1           44165952.0                f  2022-08-29 22:21:11.405
# 2           44445200.0                f  2023-04-03 14:05:29.801
# 3           44445200.0                f  2023-04-03 14:05:29.801
# 4           44219109.0                f  2023-01-20 19:34:46.622
# ...                ...              ...                      ...
# 459269             NaN              NaN                      NaN
# 459270             NaN              NaN                      NaN
# 459271             NaN              NaN                      NaN
# 459272             NaN              NaN                      NaN
# 459273             NaN              NaN                      NaN
#
#        incident_date report_date_flag  incident_hour  cleared_except_id  \
# 0         2022-04-07                f            0.0                6.0
# 1         2022-05-02                f            0.0                6.0
# 2         2022-04-07                f            0.0                6.0
# 3         2022-04-07                f            0.0                6.0
# 4         2022-10-25                f           16.0                6.0
# ...              ...              ...            ...                ...
# 459269           NaN              NaN            NaN                NaN
# 459270           NaN              NaN            NaN                NaN
# 459271           NaN              NaN            NaN                NaN
# 459272           NaN              NaN            NaN                NaN
# 459273           NaN              NaN            NaN                NaN
#
#        cleared_except_date incident_status orig_format          did  \
# 0                      NaN        ACCEPTED           X  181967491.0
# 1                      NaN        ACCEPTED           X  152981707.0
# 2                      NaN        ACCEPTED           X  181967491.0
# 3                      NaN        ACCEPTED           X  181967491.0
# 4                      NaN        ACCEPTED           X  170471177.0
# ...                    ...             ...         ...          ...
# 459269                 NaN             NaN         NaN          NaN
# 459270                 NaN             NaN         NaN          NaN
# 459271                 NaN             NaN         NaN          NaN
# 459272                 NaN             NaN         NaN          NaN
# 459273                 NaN             NaN         NaN          NaN
#
#         property_id  prop_loss_id  stolen_count  recovered_count  \
# 0               NaN           NaN           NaN              NaN
# 1               NaN           NaN           NaN              NaN
# 2               NaN           NaN           NaN              NaN
# 3               NaN           NaN           NaN              NaN
# 4               NaN           NaN           NaN              NaN
# ...             ...           ...           ...              ...
# 459269          NaN           NaN           NaN              NaN
# 459270          NaN           NaN           NaN              NaN
# 459271          NaN           NaN           NaN              NaN
# 459272          NaN           NaN           NaN              NaN
# 459273          NaN           NaN           NaN              NaN
#
#         prop_desc_id  property_value date_recovered  relationship_id  \
# 0                NaN             NaN            NaN              NaN
# 1                NaN             NaN            NaN              NaN
# 2                NaN             NaN            NaN              NaN
# 3                NaN             NaN            NaN              NaN
# 4                NaN             NaN            NaN              NaN
# ...              ...             ...            ...              ...
# 459269           NaN             NaN            NaN              NaN
# 459270           NaN             NaN            NaN              NaN
# 459271           NaN             NaN            NaN              NaN
# 459272           NaN             NaN            NaN              NaN
# 459273           NaN             NaN            NaN              NaN
#
#         criminal_act_id  weapon_id  injury_id  yearly_agency_id        ori  \
# 0                   2.0        NaN        NaN        23192022.0  FL0010000
# 1                   2.0        NaN        NaN        26152022.0  FL0160000
# 2                   5.0        NaN        NaN        23192022.0  FL0010000
# 3                   6.0        NaN        NaN        23192022.0  FL0010000
# 4                   6.0        NaN        NaN        25802022.0  FL0139100
# ...                 ...        ...        ...               ...        ...
# 459269              NaN        NaN        NaN               NaN        NaN
# 459270              NaN        NaN        NaN               NaN        NaN
# 459271              NaN        NaN        NaN               NaN        NaN
# 459272              NaN        NaN        NaN               NaN        NaN
# 459273              NaN        NaN        NaN               NaN        NaN
#
#        legacy_ori direct_contributor_flag dormant_flag reporting_type  \
# 0       FL0010000                       N            N              I
# 1       FL0160000                       N            N              I
# 2       FL0010000                       N            N              I
# 3       FL0010000                       N            N              I
# 4       FL0139100                       N            N              I
# ...           ...                     ...          ...            ...
# 459269        NaN                     NaN          NaN            NaN
# 459270        NaN                     NaN          NaN            NaN
# 459271        NaN                     NaN          NaN            NaN
# 459272        NaN                     NaN          NaN            NaN
# 459273        NaN                     NaN          NaN            NaN
#
#                       ucr_agency_name                    ncic_agency_name  \
# 0                             ALACHUA           ALACHUA CO SO GAINESVILLE
# 1       JACKSONVILLE SHERIFF'S OFFICE            DUVAL CO SO JACKSONVILLE
# 2                             ALACHUA           ALACHUA CO SO GAINESVILLE
# 3                             ALACHUA           ALACHUA CO SO GAINESVILLE
# 4                            AVENTURA  CITY OF AVENTURA POLICE DEPARTMENT
# ...                               ...                                 ...
# 459269                            NaN                                 NaN
# 459270                            NaN                                 NaN
# 459271                            NaN                                 NaN
# 459272                            NaN                                 NaN
# 459273                            NaN                                 NaN
#
#                       pub_agency_name pub_agency_unit agency_status  state_id  \
# 0                             Alachua             NaN             A      12.0
# 1       Jacksonville Sheriff's Office             NaN             A      12.0
# 2                             Alachua             NaN             A      12.0
# 3                             Alachua             NaN             A      12.0
# 4                            Aventura             NaN             A      12.0
# ...                               ...             ...           ...       ...
# 459269                            NaN             NaN           NaN       NaN
# 459270                            NaN             NaN           NaN       NaN
# 459271                            NaN             NaN           NaN       NaN
# 459272                            NaN             NaN           NaN       NaN
# 459273                            NaN             NaN           NaN       NaN
#
#        state_name state_abbr state_postal_abbr  division_code   division_name  \
# 0         Florida         FL                FL            5.0  South Atlantic
# 1         Florida         FL                FL            5.0  South Atlantic
# 2         Florida         FL                FL            5.0  South Atlantic
# 3         Florida         FL                FL            5.0  South Atlantic
# 4         Florida         FL                FL            5.0  South Atlantic
# ...           ...        ...               ...            ...             ...
# 459269        NaN        NaN               NaN            NaN             NaN
# 459270        NaN        NaN               NaN            NaN             NaN
# 459271        NaN        NaN               NaN            NaN             NaN
# 459272        NaN        NaN               NaN            NaN             NaN
# 459273        NaN        NaN               NaN            NaN             NaN
#
#         region_code region_name region_desc agency_type_name  population  \
# 0               3.0       South  Region III           County    124750.0
# 1               3.0       South  Region III           County    971282.0
# 2               3.0       South  Region III           County    124750.0
# 3               3.0       South  Region III           County    124750.0
# 4               3.0       South  Region III             City     38484.0
# ...             ...         ...         ...              ...         ...
# 459269          NaN         NaN         NaN              NaN         NaN
# 459270          NaN         NaN         NaN              NaN         NaN
# 459271          NaN         NaN         NaN              NaN         NaN
# 459272          NaN         NaN         NaN              NaN         NaN
# 459273          NaN         NaN         NaN              NaN         NaN
#
#         submitting_agency_id        sai  \
# 0                    23362.0  FLUCR0001
# 1                    23362.0  FLUCR0001
# 2                    23362.0  FLUCR0001
# 3                    23362.0  FLUCR0001
# 4                    23362.0  FLUCR0001
# ...                      ...        ...
# 459269                   NaN        NaN
# 459270                   NaN        NaN
# 459271                   NaN        NaN
# 459272                   NaN        NaN
# 459273                   NaN        NaN
#
#                                    submitting_agency_name suburban_area_flag  \
# 0       Florida Department of Law Enforcement Uniform ...                  Y
# 1       Florida Department of Law Enforcement Uniform ...                  Y
# 2       Florida Department of Law Enforcement Uniform ...                  Y
# 3       Florida Department of Law Enforcement Uniform ...                  Y
# 4       Florida Department of Law Enforcement Uniform ...                  Y
# ...                                                   ...                ...
# 459269                                                NaN                NaN
# 459270                                                NaN                NaN
# 459271                                                NaN                NaN
# 459272                                                NaN                NaN
# 459273                                                NaN                NaN
#
#         population_group_id population_group_code  \
# 0                      19.0                    9A
# 1                      19.0                    9A
# 2                      19.0                    9A
# 3                      19.0                    9A
# 4                       8.0                     4
# ...                     ...                   ...
# 459269                  NaN                   NaN
# 459270                  NaN                   NaN
# 459271                  NaN                   NaN
# 459272                  NaN                   NaN
# 459273                  NaN                   NaN
#
#                  population_group_desc  parent_pop_group_code  \
# 0         MSA counties 100,000 or over                    9.0
# 1         MSA counties 100,000 or over                    9.0
# 2         MSA counties 100,000 or over                    9.0
# 3         MSA counties 100,000 or over                    9.0
# 4       Cities from 25,000 thru 49,999                    4.0
# ...                                ...                    ...
# 459269                             NaN                    NaN
# 459270                             NaN                    NaN
# 459271                             NaN                    NaN
# 459272                             NaN                    NaN
# 459273                             NaN                    NaN
#
#                  parent_pop_group_desc mip_flag  pop_sort_order  \
# 0                         MSA Counties        Y            19.0
# 1                         MSA Counties        Y            19.0
# 2                         MSA Counties        Y            19.0
# 3                         MSA Counties        Y            19.0
# 4       Cities from 25,000 thru 49,999        N             8.0
# ...                                ...      ...             ...
# 459269                             NaN      NaN             NaN
# 459270                             NaN      NaN             NaN
# 459271                             NaN      NaN             NaN
# 459272                             NaN      NaN             NaN
# 459273                             NaN      NaN             NaN
#
#        pe_reported_flag  male_officer  male_civilian  \
# 0                     Y         227.0           41.0
# 1                     N           NaN            NaN
# 2                     Y         227.0           41.0
# 3                     Y         227.0           41.0
# 4                     Y          77.0           11.0
# ...                 ...           ...            ...
# 459269              NaN           NaN            NaN
# 459270              NaN           NaN            NaN
# 459271              NaN           NaN            NaN
# 459272              NaN           NaN            NaN
# 459273              NaN           NaN            NaN
#
#         male_officer+male_civilian  female_officer  female_civilian  \
# 0                            268.0            19.0             83.0
# 1                              NaN             NaN              NaN
# 2                            268.0            19.0             83.0
# 3                            268.0            19.0             83.0
# 4                             88.0            14.0             21.0
# ...                            ...             ...              ...
# 459269                         NaN             NaN              NaN
# 459270                         NaN             NaN              NaN
# 459271                         NaN             NaN              NaN
# 459272                         NaN             NaN              NaN
# 459273                         NaN             NaN              NaN
#
#         female_officer+female_civilian  officer_rate  employee_rate  \
# 0                                102.0           2.0            3.0
# 1                                  NaN           NaN            NaN
# 2                                102.0           2.0            3.0
# 3                                102.0           2.0            3.0
# 4                                 35.0           2.4            3.2
# ...                                ...           ...            ...
# 459269                             NaN           NaN            NaN
# 459270                             NaN           NaN            NaN
# 459271                             NaN           NaN            NaN
# 459272                             NaN           NaN            NaN
# 459273                             NaN           NaN            NaN
#
#        nibrs_cert_date nibrs_start_date nibrs_leoka_start_date  \
# 0           2021-01-01       2022-02-01             2022-05-01
# 1           2021-01-01       2021-10-01             2022-06-01
# 2           2021-01-01       2022-02-01             2022-05-01
# 3           2021-01-01       2022-02-01             2022-05-01
# 4           2021-01-01       2021-01-01             2022-06-01
# ...                ...              ...                    ...
# 459269             NaN              NaN                    NaN
# 459270             NaN              NaN                    NaN
# 459271             NaN              NaN                    NaN
# 459272             NaN              NaN                    NaN
# 459273             NaN              NaN                    NaN
#
#        nibrs_ct_start_date nibrs_multi_bias_start_date  \
# 0               2022-05-01                  2022-05-01
# 1               2022-06-01                  2022-06-01
# 2               2022-05-01                  2022-05-01
# 3               2022-05-01                  2022-05-01
# 4               2022-06-01                  2022-06-01
# ...                    ...                         ...
# 459269                 NaN                         NaN
# 459270                 NaN                         NaN
# 459271                 NaN                         NaN
# 459272                 NaN                         NaN
# 459273                 NaN                         NaN
#
#        nibrs_off_eth_start_date covered_flag county_name  \
# 0                    2022-05-01            N     ALACHUA
# 1                    2022-06-01            N       DUVAL
# 2                    2022-05-01            N     ALACHUA
# 3                    2022-05-01            N     ALACHUA
# 4                    2022-06-01            N  MIAMI-DADE
# ...                         ...          ...         ...
# 459269                      NaN          NaN         NaN
# 459270                      NaN          NaN         NaN
# 459271                      NaN          NaN         NaN
# 459272                      NaN          NaN         NaN
# 459273                      NaN          NaN         NaN
#
#                                        msa_name publishable_flag participated  \
# 0                               Gainesville, FL                Y            Y
# 1                              Jacksonville, FL                Y            Y
# 2                               Gainesville, FL                Y            Y
# 3                               Gainesville, FL                Y            Y
# 4       Miami-Fort Lauderdale-Pompano Beach, FL                Y            Y
# ...                                         ...              ...          ...
# 459269                                      NaN              NaN          NaN
# 459270                                      NaN              NaN          NaN
# 459271                                      NaN              NaN          NaN
# 459272                                      NaN              NaN          NaN
# 459273                                      NaN              NaN          NaN
#
#        nibrs_participated                  offense_name crime_against ct_flag  \
# 0                       Y  Pornography/Obscene Material       Society       f
# 1                       Y  Pornography/Obscene Material       Society       f
# 2                       Y  Pornography/Obscene Material       Society       f
# 3                       Y  Pornography/Obscene Material       Society       f
# 4                       Y  Pornography/Obscene Material       Society       f
# ...                   ...                           ...           ...     ...
# 459269                NaN                           NaN           NaN     NaN
# 459270                NaN                           NaN           NaN     NaN
# 459271                NaN                           NaN           NaN     NaN
# 459272                NaN                           NaN           NaN     NaN
# 459273                NaN                           NaN           NaN     NaN
#
#        hc_flag hc_code         offense_category_name offense_group  \
# 0            t          Pornography/Obscene Material             A
# 1            t          Pornography/Obscene Material             A
# 2            t          Pornography/Obscene Material             A
# 3            t          Pornography/Obscene Material             A
# 4            t          Pornography/Obscene Material             A
# ...        ...     ...                           ...           ...
# 459269     NaN     NaN                           NaN           NaN
# 459270     NaN     NaN                           NaN           NaN
# 459271     NaN     NaN                           NaN           NaN
# 459272     NaN     NaN                           NaN           NaN
# 459273     NaN     NaN                           NaN           NaN
#
#        prop_desc_name  prop_desc_code  location_code   location_name  \
# 0                 NaN             NaN           58.0      Cyberspace
# 1                 NaN             NaN           20.0  Residence/Home
# 2                 NaN             NaN           58.0      Cyberspace
# 3                 NaN             NaN           58.0      Cyberspace
# 4                 NaN             NaN           58.0      Cyberspace
# ...               ...             ...            ...             ...
# 459269            NaN             NaN            NaN             NaN
# 459270            NaN             NaN            NaN             NaN
# 459271            NaN             NaN            NaN             NaN
# 459272            NaN             NaN            NaN             NaN
# 459273            NaN             NaN            NaN             NaN
#
#         bias_code bias_category       bias_desc weapon_code weapon_name  \
# 0            88.0  None/Unknown  None (no bias)         NaN         NaN
# 1            88.0  None/Unknown  None (no bias)         NaN         NaN
# 2            88.0  None/Unknown  None (no bias)         NaN         NaN
# 3            88.0  None/Unknown  None (no bias)         NaN         NaN
# 4            88.0  None/Unknown  None (no bias)         NaN         NaN
# ...           ...           ...             ...         ...         ...
# 459269        NaN           NaN             NaN         NaN         NaN
# 459270        NaN           NaN             NaN         NaN         NaN
# 459271        NaN           NaN             NaN         NaN         NaN
# 459272        NaN           NaN             NaN         NaN         NaN
# 459273        NaN           NaN             NaN         NaN         NaN
#
#        shr_flag relationship_code relationship_name  circumstances_id  \
# 0           NaN               NaN               NaN               NaN
# 1           NaN               NaN               NaN               NaN
# 2           NaN               NaN               NaN               NaN
# 3           NaN               NaN               NaN               NaN
# 4           NaN               NaN               NaN               NaN
# ...         ...               ...               ...               ...
# 459269      NaN               NaN               NaN              30.0
# 459270      NaN               NaN               NaN              31.0
# 459271      NaN               NaN               NaN              32.0
# 459272      NaN               NaN               NaN              33.0
# 459273      NaN               NaN               NaN              34.0
#
#         justifiable_force_id circumstance_type  circumstance_code  \
# 0                        NaN               NaN                NaN
# 1                        NaN               NaN                NaN
# 2                        NaN               NaN                NaN
# 3                        NaN               NaN                NaN
# 4                        NaN               NaN                NaN
# ...                      ...               ...                ...
# 459269                   NaN                 N               30.0
# 459270                   NaN                 N               31.0
# 459271                   NaN                 N               32.0
# 459272                   NaN                 N               33.0
# 459273                   NaN                 N               34.0
#
#                       circumstance_name criminal_act_code  \
# 0                                   NaN                 C
# 1                                   NaN                 C
# 2                                   NaN                 O
# 3                                   NaN                 P
# 4                                   NaN                 P
# ...                                 ...               ...
# 459269        Child Playing With Weapon               NaN
# 459270            Gun-Cleaning Accident               NaN
# 459271                 Hunting Accident               NaN
# 459272  Other Negligent Weapon Handling               NaN
# 459273         Other Negligent Killings               NaN
#
#                            criminal_act_name  \
# 0       Cultivating/Manufacturing/Publishing
# 1       Cultivating/Manufacturing/Publishing
# 2              Operating/Promoting/Assisting
# 3                      Possessing/Concealing
# 4                      Possessing/Concealing
# ...                                      ...
# 459269                                   NaN
# 459270                                   NaN
# 459271                                   NaN
# 459272                                   NaN
# 459273                                   NaN
#
#                                         criminal_act_desc  activity_type_code  \
# 0       Cultivating/Manufacturing/Publishing (i.e., pr...                 NaN
# 1       Cultivating/Manufacturing/Publishing (i.e., pr...                 NaN
# 2                           Operating/Promoting/Assisting                 NaN
# 3                                   Possessing/Concealing                 NaN
# 4                                   Possessing/Concealing                 NaN
# ...                                                   ...                 ...
# 459269                                                NaN                 NaN
# 459270                                                NaN                 NaN
# 459271                                                NaN                 NaN
# 459272                                                NaN                 NaN
# 459273                                                NaN                 NaN
#
#        activity_type_name victim_type_code victim_type_name prop_loss_name  \
# 0                     NaN                S   Society/Public            NaN
# 1                     NaN                S   Society/Public            NaN
# 2                     NaN                S   Society/Public            NaN
# 3                     NaN                S   Society/Public            NaN
# 4                     NaN                S   Society/Public            NaN
# ...                   ...              ...              ...            ...
# 459269                NaN              NaN              NaN            NaN
# 459270                NaN              NaN              NaN            NaN
# 459271                NaN              NaN              NaN            NaN
# 459272                NaN              NaN              NaN            NaN
# 459273                NaN              NaN              NaN            NaN
#
#        prop_loss_desc injury_code injury_name suspect_using_code  \
# 0                 NaN         NaN         NaN                  C
# 1                 NaN         NaN         NaN                  C
# 2                 NaN         NaN         NaN                  C
# 3                 NaN         NaN         NaN                  C
# 4                 NaN         NaN         NaN                  C
# ...               ...         ...         ...                ...
# 459269            NaN         NaN         NaN                NaN
# 459270            NaN         NaN         NaN                NaN
# 459271            NaN         NaN         NaN                NaN
# 459272            NaN         NaN         NaN                NaN
# 459273            NaN         NaN         NaN                NaN
#
#                            suspect_using_name
# 0       Computer Equipment (Handheld Devices)
# 1       Computer Equipment (Handheld Devices)
# 2       Computer Equipment (Handheld Devices)
# 3       Computer Equipment (Handheld Devices)
# 4       Computer Equipment (Handheld Devices)
# ...                                       ...
# 459269                                    NaN
# 459270                                    NaN
# 459271                                    NaN
# 459272                                    NaN
# 459273                                    NaN
#
# [459274 rows x 166 columns]

# %%
# # Reducing dataframe to columns that are relevant for the analysis
offender_columns = [
    'offender_id', 
    'age_num_offender',
    'sex_code_offender', 
     'race_code_offender', 'race_desc_offender', 
    'ethnicity_code_offender', 'ethnicity_name_offender', 
    'offense_id', 
   'offense_code', 
    'offense_category_name', 'offense_group', 
    'incident_id', 'incident_date',
    'crime_against', 
    'agency_id', 'county_name', 'msa_name', 
    'location_id', 'location_name', 
    'relationship_name', 
    'weapon_id','weapon_name', 
    'suspect_using_code', 'suspect_using_name'
]
df_offenders = df_cleaned[offender_columns]
df_offenders.head()
# Out:
#    offender_id age_num_offender sex_code_offender race_code_offender  \
# 0  191997464.0               30                 M                  W
# 1  179473577.0               24                 M                  B
# 2  191997464.0               30                 M                  W
# 3  191997464.0               30                 M                  W
# 4  187239644.0               00                 X                 NS
#
#           race_desc_offender ethnicity_code_offender ethnicity_name_offender  \
# 0                      White                       N  Not Hispanic or Latino
# 1  Black or African American                       U                 Unknown
# 2                      White                       N  Not Hispanic or Latino
# 3                      White                       N  Not Hispanic or Latino
# 4              Not Specified                       X           Not Specified
#
#     offense_id offense_code         offense_category_name offense_group  \
# 0  201782413.0          370  Pornography/Obscene Material             A
# 1  189055071.0          370  Pornography/Obscene Material             A
# 2  201782413.0          370  Pornography/Obscene Material             A
# 3  201782413.0          370  Pornography/Obscene Material             A
# 4  196943710.0          370  Pornography/Obscene Material             A
#
#    incident_id incident_date crime_against  agency_id county_name  \
# 0  169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 1  158047235.0    2022-05-02       Society     2615.0       DUVAL
# 2  169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 3  169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 4  164923714.0    2022-10-25       Society     2580.0  MIAMI-DADE
#
#                                   msa_name  location_id   location_name  \
# 0                          Gainesville, FL         15.0      Cyberspace
# 1                         Jacksonville, FL         35.0  Residence/Home
# 2                          Gainesville, FL         15.0      Cyberspace
# 3                          Gainesville, FL         15.0      Cyberspace
# 4  Miami-Fort Lauderdale-Pompano Beach, FL         15.0      Cyberspace
#
#   relationship_name  weapon_id weapon_name suspect_using_code  \
# 0               NaN        NaN         NaN                  C
# 1               NaN        NaN         NaN                  C
# 2               NaN        NaN         NaN                  C
# 3               NaN        NaN         NaN                  C
# 4               NaN        NaN         NaN                  C
#
#                       suspect_using_name
# 0  Computer Equipment (Handheld Devices)
# 1  Computer Equipment (Handheld Devices)
# 2  Computer Equipment (Handheld Devices)
# 3  Computer Equipment (Handheld Devices)
# 4  Computer Equipment (Handheld Devices)

# %%
# Rename columns
df_offenders = df_offenders.rename(columns={
    'age_num_offender':'offender_age',
    'sex_code_offender':'offender_sex',
    'race_code_offender':'offender_race',
    'race_desc_offender':'race_description',
    'ethnicity_code_offender':'offender_ethnicity',
    'ethnicity_name_offender': 'ethnicity_description',
    'msa_name':'city_name',
    'location_name':'offense_location',
    'relationship_name':'offender_victim_relationship',
    'weapon_name':'weapon_used',
    'suspect_using_code':'offender_using_code',
    'suspect_using_name':'offender_using_name'
})

df_offenders
# Out:
#         offender_id offender_age offender_sex offender_race  \
# 0       191997464.0           30            M             W
# 1       179473577.0           24            M             B
# 2       191997464.0           30            M             W
# 3       191997464.0           30            M             W
# 4       187239644.0           00            X            NS
# ...             ...          ...          ...           ...
# 459269          NaN          NaN          NaN           NaN
# 459270          NaN          NaN          NaN           NaN
# 459271          NaN          NaN          NaN           NaN
# 459272          NaN          NaN          NaN           NaN
# 459273          NaN          NaN          NaN           NaN
#
#                  race_description offender_ethnicity   ethnicity_description  \
# 0                           White                  N  Not Hispanic or Latino
# 1       Black or African American                  U                 Unknown
# 2                           White                  N  Not Hispanic or Latino
# 3                           White                  N  Not Hispanic or Latino
# 4                   Not Specified                  X           Not Specified
# ...                           ...                ...                     ...
# 459269                        NaN                NaN                     NaN
# 459270                        NaN                NaN                     NaN
# 459271                        NaN                NaN                     NaN
# 459272                        NaN                NaN                     NaN
# 459273                        NaN                NaN                     NaN
#
#          offense_id offense_code         offense_category_name offense_group  \
# 0       201782413.0          370  Pornography/Obscene Material             A
# 1       189055071.0          370  Pornography/Obscene Material             A
# 2       201782413.0          370  Pornography/Obscene Material             A
# 3       201782413.0          370  Pornography/Obscene Material             A
# 4       196943710.0          370  Pornography/Obscene Material             A
# ...             ...          ...                           ...           ...
# 459269          NaN          NaN                           NaN           NaN
# 459270          NaN          NaN                           NaN           NaN
# 459271          NaN          NaN                           NaN           NaN
# 459272          NaN          NaN                           NaN           NaN
# 459273          NaN          NaN                           NaN           NaN
#
#         incident_id incident_date crime_against  agency_id county_name  \
# 0       169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 1       158047235.0    2022-05-02       Society     2615.0       DUVAL
# 2       169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 3       169127885.0    2022-04-07       Society     2319.0     ALACHUA
# 4       164923714.0    2022-10-25       Society     2580.0  MIAMI-DADE
# ...             ...           ...           ...        ...         ...
# 459269          NaN           NaN           NaN        NaN         NaN
# 459270          NaN           NaN           NaN        NaN         NaN
# 459271          NaN           NaN           NaN        NaN         NaN
# 459272          NaN           NaN           NaN        NaN         NaN
# 459273          NaN           NaN           NaN        NaN         NaN
#
#                                       city_name  location_id offense_location  \
# 0                               Gainesville, FL         15.0       Cyberspace
# 1                              Jacksonville, FL         35.0   Residence/Home
# 2                               Gainesville, FL         15.0       Cyberspace
# 3                               Gainesville, FL         15.0       Cyberspace
# 4       Miami-Fort Lauderdale-Pompano Beach, FL         15.0       Cyberspace
# ...                                         ...          ...              ...
# 459269                                      NaN          NaN              NaN
# 459270                                      NaN          NaN              NaN
# 459271                                      NaN          NaN              NaN
# 459272                                      NaN          NaN              NaN
# 459273                                      NaN          NaN              NaN
#
#        offender_victim_relationship  weapon_id weapon_used  \
# 0                               NaN        NaN         NaN
# 1                               NaN        NaN         NaN
# 2                               NaN        NaN         NaN
# 3                               NaN        NaN         NaN
# 4                               NaN        NaN         NaN
# ...                             ...        ...         ...
# 459269                          NaN        NaN         NaN
# 459270                          NaN        NaN         NaN
# 459271                          NaN        NaN         NaN
# 459272                          NaN        NaN         NaN
# 459273                          NaN        NaN         NaN
#
#        offender_using_code                    offender_using_name
# 0                        C  Computer Equipment (Handheld Devices)
# 1                        C  Computer Equipment (Handheld Devices)
# 2                        C  Computer Equipment (Handheld Devices)
# 3                        C  Computer Equipment (Handheld Devices)
# 4                        C  Computer Equipment (Handheld Devices)
# ...                    ...                                    ...
# 459269                 NaN                                    NaN
# 459270                 NaN                                    NaN
# 459271                 NaN                                    NaN
# 459272                 NaN                                    NaN
# 459273                 NaN                                    NaN
#
# [459274 rows x 24 columns]

# %%
# Removing rows where all values are null
df_offenders = df_offenders.dropna(how='any')
df_offenders
# Out:
#         offender_id offender_age offender_sex offender_race  \
# 250     179473023.0           30            M             B
# 251     179473024.0           23            M             B
# 271     193172405.0           27            M             B
# 2095    183959489.0           36            M             U
# 2096    192047850.0           48            M             W
# ...             ...          ...          ...           ...
# 459132  183025330.0           50            M             W
# 459133  192675786.0           44            F             W
# 459134  192675787.0           44            M             W
# 459135  181448347.0           39            M             W
# 459136  181448347.0           39            M             W
#
#                  race_description offender_ethnicity   ethnicity_description  \
# 250     Black or African American                  N  Not Hispanic or Latino
# 251     Black or African American                  N  Not Hispanic or Latino
# 271     Black or African American                  N  Not Hispanic or Latino
# 2095                      Unknown                  X           Not Specified
# 2096                        White                  N  Not Hispanic or Latino
# ...                           ...                ...                     ...
# 459132                      White                  H      Hispanic or Latino
# 459133                      White                  X           Not Specified
# 459134                      White                  X           Not Specified
# 459135                      White                  X           Not Specified
# 459136                      White                  X           Not Specified
#
#          offense_id offense_code offense_category_name offense_group  \
# 250     189054496.0          09A     Homicide Offenses             A
# 251     189054496.0          09A     Homicide Offenses             A
# 271     202968209.0          09A     Homicide Offenses             A
# 2095    193621678.0          13B      Assault Offenses             A
# 2096    201836372.0          13B      Assault Offenses             A
# ...             ...          ...                   ...           ...
# 459132  192678151.0          120               Robbery             A
# 459133  202469165.0          120               Robbery             A
# 459134  202469165.0          120               Robbery             A
# 459135  191056945.0          120               Robbery             A
# 459136  191056945.0          120               Robbery             A
#
#         incident_id incident_date crime_against  agency_id county_name  \
# 250     158046739.0    2022-01-02        Person     2615.0       DUVAL
# 251     158046739.0    2022-01-02        Person     2615.0       DUVAL
# 271     170162138.0    2022-05-19        Person     3203.0    PINELLAS
# 2095    162020342.0    2022-01-21        Person     2920.0        LEON
# 2096    169173148.0    2022-06-21        Person     2920.0        LEON
# ...             ...           ...           ...        ...         ...
# 459132  161193668.0    2022-10-29      Property     2513.0     COLLIER
# 459133  169726563.0    2022-06-26      Property     3026.0      MONROE
# 459134  169726563.0    2022-06-26      Property     3026.0      MONROE
# 459135  159790574.0    2022-01-26      Property     2539.0  MIAMI-DADE
# 459136  159790574.0    2022-01-26      Property     2539.0  MIAMI-DADE
#
#                                       city_name  location_id  \
# 250                            Jacksonville, FL         35.0
# 251                            Jacksonville, FL         35.0
# 271         Tampa-St. Petersburg-Clearwater, FL         35.0
# 2095                            Tallahassee, FL         35.0
# 2096                            Tallahassee, FL         98.0
# ...                                         ...          ...
# 459132                  Naples-Marco Island, FL         25.0
# 459133                            Not Specified         21.0
# 459134                            Not Specified         21.0
# 459135  Miami-Fort Lauderdale-Pompano Beach, FL         33.0
# 459136  Miami-Fort Lauderdale-Pompano Beach, FL         33.0
#
#                           offense_location offender_victim_relationship  \
# 250                         Residence/Home         Relationship Unknown
# 251                         Residence/Home         Relationship Unknown
# 271                         Residence/Home      Victim Was Acquaintance
# 2095                        Residence/Home         Relationship Unknown
# 2096                         Other/Unknown         Relationship Unknown
# ...                                    ...                          ...
# 459132  Highway/Road/Alley/Street/Sidewalk          Victim Was Stranger
# 459133                         Field/Woods          Victim Was Stranger
# 459134                         Field/Woods          Victim Was Stranger
# 459135             Parking/Drop Lot/Garage          Victim Was Stranger
# 459136             Parking/Drop Lot/Garage          Victim Was Stranger
#
#         weapon_id       weapon_used offender_using_code  \
# 250           3.0           Handgun                   C
# 251           3.0           Handgun                   C
# 271           1.0           Firearm                   C
# 2095         41.0  Personal Weapons                   C
# 2096         41.0  Personal Weapons                   C
# ...           ...               ...                 ...
# 459132       41.0  Personal Weapons                   A
# 459133       41.0  Personal Weapons                   A
# 459134       41.0  Personal Weapons                   A
# 459135       38.0             Other                   A
# 459136       38.0             Other                   A
#
#                           offender_using_name
# 250     Computer Equipment (Handheld Devices)
# 251     Computer Equipment (Handheld Devices)
# 271     Computer Equipment (Handheld Devices)
# 2095    Computer Equipment (Handheld Devices)
# 2096    Computer Equipment (Handheld Devices)
# ...                                       ...
# 459132                                Alcohol
# 459133                                Alcohol
# 459134                                Alcohol
# 459135                                Alcohol
# 459136                                Alcohol
#
# [91794 rows x 24 columns]

# %%
# Removing duplicates rows based on all columns
df_offenders = df_offenders.drop_duplicates()
df_offenders.count()
# Out:
# offender_id                     73534
# offender_age                    73534
# offender_sex                    73534
# offender_race                   73534
# race_description                73534
# offender_ethnicity              73534
# ethnicity_description           73534
# offense_id                      73534
# offense_code                    73534
# offense_category_name           73534
# offense_group                   73534
# incident_id                     73534
# incident_date                   73534
# crime_against                   73534
# agency_id                       73534
# county_name                     73534
# city_name                       73534
# location_id                     73534
# offense_location                73534
# offender_victim_relationship    73534
# weapon_id                       73534
# weapon_used                     73534
# offender_using_code             73534
# offender_using_name             73534
# dtype: int64

# %%
# Exploring data types
df_offenders.dtypes
# Out:
# offender_id                     float64
# offender_age                     object
# offender_sex                     object
# offender_race                    object
# race_description                 object
# offender_ethnicity               object
# ethnicity_description            object
# offense_id                      float64
# offense_code                     object
# offense_category_name            object
# offense_group                    object
# incident_id                     float64
# incident_date                    object
# crime_against                    object
# agency_id                       float64
# county_name                      object
# city_name                        object
# location_id                     float64
# offense_location                 object
# offender_victim_relationship     object
# weapon_id                       float64
# weapon_used                      object
# offender_using_code              object
# offender_using_name              object
# dtype: object

# %%
# Transforming data types
# To datetime
df_offenders['incident_date'] = pd.to_datetime(df_offenders['incident_date'])
# To int
int_columns = ['offender_id','offender_age','offense_id', 'incident_id', 'agency_id','location_id','weapon_id']
df_offenders[int_columns] = df_offenders[int_columns].astype('int64')
df_offenders.dtypes
# Out:
# /var/folders/2v/w2v_wk9d5978rkz6gq_ydlqm0000gn/T/ipykernel_16304/2161224831.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_offenders['incident_date'] = pd.to_datetime(df_offenders['incident_date'])
# /var/folders/2v/w2v_wk9d5978rkz6gq_ydlqm0000gn/T/ipykernel_16304/2161224831.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_offenders[int_columns] = df_offenders[int_columns].astype('int64')
# offender_id                              int64
# offender_age                             int64
# offender_sex                            object
# offender_race                           object
# race_description                        object
# offender_ethnicity                      object
# ethnicity_description                   object
# offense_id                               int64
# offense_code                            object
# offense_category_name                   object
# offense_group                           object
# incident_id                              int64
# incident_date                   datetime64[ns]
# crime_against                           object
# agency_id                                int64
# county_name                             object
# city_name                               object
# location_id                              int64
# offense_location                        object
# offender_victim_relationship            object
# weapon_id                                int64
# weapon_used                             object
# offender_using_code                     object
# offender_using_name                     object
# dtype: object

# %%
# Reseting the index 
df_offenders = df_offenders.reset_index(drop=True)
df_offenders
# Out:
#        offender_id  offender_age offender_sex offender_race  \
# 0        179473023            30            M             B
# 1        179473024            23            M             B
# 2        193172405            27            M             B
# 3        183959489            36            M             U
# 4        192047850            48            M             W
# ...            ...           ...          ...           ...
# 73529    191045722            24            M             W
# 73530    178290534            37            F             B
# 73531    183025329            50            M             W
# 73532    183025330            50            M             W
# 73533    181448347            39            M             W
#
#                 race_description offender_ethnicity   ethnicity_description  \
# 0      Black or African American                  N  Not Hispanic or Latino
# 1      Black or African American                  N  Not Hispanic or Latino
# 2      Black or African American                  N  Not Hispanic or Latino
# 3                        Unknown                  X           Not Specified
# 4                          White                  N  Not Hispanic or Latino
# ...                          ...                ...                     ...
# 73529                      White                  H      Hispanic or Latino
# 73530  Black or African American                  N  Not Hispanic or Latino
# 73531                      White                  H      Hispanic or Latino
# 73532                      White                  H      Hispanic or Latino
# 73533                      White                  X           Not Specified
#
#        offense_id offense_code offense_category_name offense_group  \
# 0       189054496          09A     Homicide Offenses             A
# 1       189054496          09A     Homicide Offenses             A
# 2       202968209          09A     Homicide Offenses             A
# 3       193621678          13B      Assault Offenses             A
# 4       201836372          13B      Assault Offenses             A
# ...           ...          ...                   ...           ...
# 73529   200806000          13A      Assault Offenses             A
# 73530   187867664          13A      Assault Offenses             A
# 73531   192678151          120               Robbery             A
# 73532   192678151          120               Robbery             A
# 73533   191056945          120               Robbery             A
#
#        incident_id incident_date crime_against  agency_id county_name  \
# 0        158046739    2022-01-02        Person       2615       DUVAL
# 1        158046739    2022-01-02        Person       2615       DUVAL
# 2        170162138    2022-05-19        Person       3203    PINELLAS
# 3        162020342    2022-01-21        Person       2920        LEON
# 4        169173148    2022-06-21        Person       2920        LEON
# ...            ...           ...           ...        ...         ...
# 73529    168290869    2022-07-28        Person       2545  MIAMI-DADE
# 73530    157009654    2022-04-16        Person       2615       DUVAL
# 73531    161193668    2022-10-29      Property       2513     COLLIER
# 73532    161193668    2022-10-29      Property       2513     COLLIER
# 73533    159790574    2022-01-26      Property       2539  MIAMI-DADE
#
#                                      city_name  location_id  \
# 0                             Jacksonville, FL           35
# 1                             Jacksonville, FL           35
# 2          Tampa-St. Petersburg-Clearwater, FL           35
# 3                              Tallahassee, FL           35
# 4                              Tallahassee, FL           98
# ...                                        ...          ...
# 73529  Miami-Fort Lauderdale-Pompano Beach, FL            8
# 73530                         Jacksonville, FL           25
# 73531                  Naples-Marco Island, FL           25
# 73532                  Naples-Marco Island, FL           25
# 73533  Miami-Fort Lauderdale-Pompano Beach, FL           33
#
#                          offense_location offender_victim_relationship  \
# 0                          Residence/Home         Relationship Unknown
# 1                          Residence/Home         Relationship Unknown
# 2                          Residence/Home      Victim Was Acquaintance
# 3                          Residence/Home         Relationship Unknown
# 4                           Other/Unknown         Relationship Unknown
# ...                                   ...                          ...
# 73529                       Bar/Nightclub          Victim Was Stranger
# 73530  Highway/Road/Alley/Street/Sidewalk          Victim Was Stranger
# 73531  Highway/Road/Alley/Street/Sidewalk          Victim Was Stranger
# 73532  Highway/Road/Alley/Street/Sidewalk          Victim Was Stranger
# 73533             Parking/Drop Lot/Garage          Victim Was Stranger
#
#        weapon_id       weapon_used offender_using_code  \
# 0              3           Handgun                   C
# 1              3           Handgun                   C
# 2              1           Firearm                   C
# 3             41  Personal Weapons                   C
# 4             41  Personal Weapons                   C
# ...          ...               ...                 ...
# 73529         41  Personal Weapons                   A
# 73530         41  Personal Weapons                   A
# 73531         41  Personal Weapons                   A
# 73532         41  Personal Weapons                   A
# 73533         38             Other                   A
#
#                          offender_using_name
# 0      Computer Equipment (Handheld Devices)
# 1      Computer Equipment (Handheld Devices)
# 2      Computer Equipment (Handheld Devices)
# 3      Computer Equipment (Handheld Devices)
# 4      Computer Equipment (Handheld Devices)
# ...                                      ...
# 73529                                Alcohol
# 73530                                Alcohol
# 73531                                Alcohol
# 73532                                Alcohol
# 73533                                Alcohol
#
# [73534 rows x 24 columns]

# %%
# Saving the DataFrame to a CSV file. 
df_offenders.to_csv('offenders_data.csv', index=False)
