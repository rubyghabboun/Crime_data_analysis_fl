# %%
import pandas as pd

# %%
df = pd.read_excel("Resources/Total_Arrests_by_County_2020.xlsx")

# %%
df
# Out:
#             Arrest Totals and Index Arrests by County Unnamed: 1  Unnamed: 2  \
# 0                             January - December 2020        NaN         NaN
# 1                                                 NaN        NaN         NaN
# 2                                              County       Year  Population
# 3                                                 NaN        NaN         NaN
# 4                                      Alachua County       2020      271588
# ..                                                ...        ...         ...
# 71                                                NaN        NaN         NaN
# 72                                            Florida       2020    21596068
# 73                                                NaN        NaN         NaN
# 74                                    Updated 09/2022        NaN         NaN
# 75  SOURCE: Florida Department of Law Enforcement....        NaN         NaN
#
# ...
