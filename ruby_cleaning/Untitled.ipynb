# %% [markdown]
# Total arrests and crime by county.

# %%
import pandas as pd

# %%
df = pd.read_excel("Resources/Total_Arrests_by_County_2020.xlsx")

# %%
df.head()
# Out:
#             County    Year  Population  Total Arrests  \
# 0   Alachua County  2020.0    271588.0         5919.0
# 1     Baker County  2020.0     28532.0          951.0
# 2       Bay County  2020.0    174410.0        13994.0
# 3  Bradford County  2020.0     28725.0         1002.0
# 4   Brevard County  2020.0    606671.0        17229.0
#
#    Arrest Rate per 100,000  Total Adult Arrests  Total Juvenile Arrests  \
# 0                   2179.4               5460.0                   459.0
# 1                   3333.1                912.0                    39.0
# 2                   8023.6              13198.0                   796.0
# 3                   3488.3                965.0                    37.0
# 4                   2839.9              16094.0                  1135.0
#
#    Murder  Rape  Robbery  ...  Intimidation  Prostitution  \
# 0    13.0  54.0    128.0  ...           7.0           0.0
# 1     2.0   4.0      0.0  ...           9.0           0.0
# ...

# %%
df.columns
# Out:
# Index(['County', 'Year', 'Population', 'Total Arrests',
#        'Arrest Rate per 100,000', 'Total Adult Arrests',
#        'Total Juvenile Arrests', 'Murder', 'Rape', 'Robbery',
#        'Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft',
#        'Manslaughter', 'Kidnap/\nAbduction', 'Arson', 'Simple Assault',
#        'Drug Arrest', 'Bribery', 'Embezzlement', 'Fraud',
#        'Counterfeit/\nForgery', 'Extortion/\nBlackmail', 'Intimidation',
#        'Prostitution', 'Non-Forcible Sex Offenses', 'Stolen Property', 'DUI',
#        'Destruction/\nVandalism', 'Gambling', 'Weapons Violations',
#        'Liquor Law Violations', 'Misc.'],
#       dtype='object')

# %%
columns_to_keep = ['County', 'Year', 'Total Arrests', 'Total Adult Arrests', 'Total Juvenile Arrests',
                   'Murder', 'Rape', 'Robbery', 'Burglary', 'Larceny', 'Motor Vehicle Theft',
                   'Stolen Property','Kidnap/\nAbduction', 'Drug Arrest', 'Aggravated Assault']

# Select only the desired columns
df_filtered = df[columns_to_keep]
df_filtered.head()
# Out:
#             County    Year  Total Arrests  Total Adult Arrests  \
# 0   Alachua County  2020.0         5919.0               5460.0
# 1     Baker County  2020.0          951.0                912.0
# 2       Bay County  2020.0        13994.0              13198.0
# 3  Bradford County  2020.0         1002.0                965.0
# 4   Brevard County  2020.0        17229.0              16094.0
#
#    Total Juvenile Arrests  Murder  Rape  Robbery  Burglary  Larceny  \
# 0                   459.0    13.0  54.0    128.0     403.0    717.0
# 1                    39.0     2.0   4.0      0.0      14.0     36.0
# 2                   796.0    10.0  32.0     27.0     591.0   1680.0
# 3                    37.0     4.0   6.0      4.0       9.0     85.0
# 4                  1135.0    34.0  38.0    138.0     500.0   1382.0
#
#    Motor Vehicle Theft  Stolen Property  Kidnap/\nAbduction  Drug Arrest  \
# 0                124.0             27.0                14.0        631.0
# ...

# %%
columns_to_convert = ['Year', 'Total Arrests', 'Total Adult Arrests', 'Total Juvenile Arrests',
                      'Murder', 'Rape', 'Robbery', 'Burglary', 'Larceny', 'Motor Vehicle Theft',
                      'Stolen Property', 'Kidnap/\nAbduction', 'Drug Arrest', 'Aggravated Assault']

df_filtered[columns_to_convert] = df_filtered[columns_to_convert].fillna(0).astype(int)

# View the converted columns
df_filtered
# Out:
# C:\Users\ruby_\AppData\Local\Temp\ipykernel_2224\625284856.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[columns_to_convert] = df_filtered[columns_to_convert].fillna(0).astype(int)
#                County  Year  Total Arrests  Total Adult Arrests  \
# 0      Alachua County  2020           5919                 5460
# 1        Baker County  2020            951                  912
# 2          Bay County  2020          13994                13198
# 3     Bradford County  2020           1002                  965
# 4      Brevard County  2020          17229                16094
# ..                ...   ...            ...                  ...
# 64     Wakulla County  2020            716                  661
# ...

# %%
#merge Robbery,Burglary,Larceny,Motor Vehicle Theft, Stolen Property to one column ( thift)
df_filtered['Theft'] = df_filtered[['Robbery', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Stolen Property']].sum(axis=1)

# Drop the individual columns (Robbery, Burglary, Larceny, Motor Vehicle Theft, Stolen Property)
df_filtered = df_filtered.drop(['Robbery', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Stolen Property'], axis=1)

# View the modified DataFrame
df_filtered.head()
# Out:
# C:\Users\ruby_\AppData\Local\Temp\ipykernel_2224\3996479844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Theft'] = df_filtered[['Robbery', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Stolen Property']].sum(axis=1)
#             County  Year  Total Arrests  Total Adult Arrests  \
# 0   Alachua County  2020           5919                 5460
# 1     Baker County  2020            951                  912
# 2       Bay County  2020          13994                13198
# 3  Bradford County  2020           1002                  965
# 4   Brevard County  2020          17229                16094
#
#    Total Juvenile Arrests  Murder  Rape  Kidnap/\nAbduction  Drug Arrest  \
# ...

# %%
df_filtered.tail()
# Out:
#                County  Year  Total Arrests  Total Adult Arrests  \
# 64     Wakulla County  2020            716                  661
# 65      Walton County  2020           2437                 2254
# 66  Washington County  2020            607                  580
# 67                NaN     0              0                    0
# 68            Florida  2020         508490               476947
#
#     Total Juvenile Arrests  Murder  Rape  Kidnap/\nAbduction  Drug Arrest  \
# 64                      55       2     2                   0          140
# 65                     183       1    13                   0          253
# 66                      27       1     0                   0          206
# 67                       0       0     0                   0            0
# 68                   31543     844  1817                 642        68661
#
#     Aggravated Assault  Theft
# 64                  46    128
# 65                  81    290
# 66                  29     79
# ...

# %%
df_filtered = df_filtered.drop(67)

# Reset the index after dropping the row
df_filtered = df_filtered.reset_index(drop=True)

# %%
# Drop row 68 florida totals
df_filtered = df_filtered.drop(index=67)

# %%
df_filtered = df_filtered.rename(columns={'Kidnap/\nAbduction': 'Kidnap and Abduction'})

# %%
df_filtered.tail()
# Out:
#                County  Year  Total Arrests  Total Adult Arrests  \
# 62       Union County  2020            307                  292
# 63     Volusia County  2020          21850                20970
# 64     Wakulla County  2020            716                  661
# 65      Walton County  2020           2437                 2254
# 66  Washington County  2020            607                  580
#
#     Total Juvenile Arrests  Murder  Rape  Kidnap and Abduction  Drug Arrest  \
# 62                      15       1     3                     1           28
# 63                     880      22    43                    58         2731
# 64                      55       2     2                     0          140
# 65                     183       1    13                     0          253
# 66                      27       1     0                     0          206
#
#     Aggravated Assault  Theft
# 62                  15     40
# 63                1194   2332
# ...

# %%
df_filtered.to_csv('filtered_data2.csv', index=False)
df_filtered.to_excel('filtered_data2.xlsx', index=False)
