# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_names= ['FIBRS_2021.csv', 'FIBRS_2022 .csv', 'FIBRS_2023_Q2 .csv']
dfs = [pd.read_csv(f'data/{file}', header=[0, 1]) for file in file_names]
df = pd.concat(dfs, ignore_index=True)

# %%
df.head(5)
# Out:
#   Unnamed: 0_level_0                       Unnamed: 1_level_0  \
#               County                              Agency Name
# 0            Alachua  University of Florida Police Department
# 1              Baker            Baker County Sheriff's Office
# 2            Brevard               Palm Bay Police Department
# 3          Charlotte        Charlotte County Sheriff's Office
# 4            Collier          Collier County Sheriff's Office
#
#    2021 Population Estimate Violent Crime Unnamed: 4_level_0 Property Crime  \
#          Unnamed: 2_level_1  Year to Date        Annual Rate   Year to Date
# 0                         0             0                 --             10
# 1                    28,692            54              188.2            196
# 2                   122,765           424              345.4          1,428
# 3                   170,933           241              141.0          1,419
# ...

# %%
plt.figure(figsize=(12, 8))

# Iterate over unique counties
for county in df['County'].unique():
    county_data = df[df['County'] == county]

    # Plot line for each agency
    for index, row in county_data.iterrows():
        crime_categories = ['Violent Crime', 'Property Crime', 'Other Crime']
        annual_rates = [row[f'{category} Annual Rate'] for category in crime_categories]

        plt.plot(crime_categories, annual_rates, label=f"{row['Agency Name']} - {row['County']}")

# Customize the chart
plt.title('Crime Rates by Agency and County (2022)')
plt.xlabel('Crime Category')
plt.ylabel('Annual Rate')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 plt.figure(figsize=(12, 8))
#       3 # Iterate over unique counties
# ...
